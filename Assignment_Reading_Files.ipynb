# %% [markdown]
# <a href="https://colab.research.google.com/github/JapiKredi/Pinnacle_AI_program_AnalyticsVidyha/blob/main/Assignment_Reading_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ---
#
# <center> <h1>📍 📍 Assignment: Reading Files 📍 📍</h1> </center>
#
# ---
#
# #### `1. READ THE BIG MART SALES DATA`
#
# ---

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/Assignment_ReadingFiles_Pandas/dataset/big_mart_sales.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-16-0c56e6fd2b2f> in <cell line: 1>()
# ----> 1 data = pd.read_csv('/content/drive/My Drive/Assignment_ReadingFiles_Pandas/dataset/big_mart_sales.csv')
#
# ...

# %% [markdown]
# ---
#
# ***So, we are getting an error. You task is to find out the error and read the file using pandas. Here is the screenshot of the CSV file.***
#
# ![](images/csv.png)
#
# ---

# %%
data_100 = pd.read_csv('/content/drive/My Drive/big_mart_sales.csv', nrows=100)

# %%
data_100.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_100_200 = pd.read_csv('/content/drive/My Drive/big_mart_sales.csv',skiprows=101, nrows=100)
data_100_200.columns = data_100.columns

# %%
data_100_200.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDD10          NaN          Regular         0.045798  Snack Foods
# 1           FDW57         8.31          Regular         0.115857  Snack Foods
# 2           DRB48        16.75          Regular         0.024833  Soft Drinks
# 3           FDP09        19.75          Low Fat         0.034028  Snack Foods
# 4           FDH14        17.10          Regular         0.046770       Canned
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  178.5344            OUT027                       1985      Medium
# 1  179.1028            OUT049                       1999      Medium
# 2   38.7822            OUT013                       1987        High
# 3  212.0902            OUT018                       2009      Medium
# 4  141.1838            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
data_200_300 = pd.read_csv('/content/drive/My Drive/big_mart_sales.csv',skiprows=201, nrows=100)
data_200_300.columns = data_100.columns

# %%
data_200_300.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDE36         5.26          Regular         0.041764
# 1           FDN57        18.25          Low Fat         0.054344
# 2           FDI24          NaN          Low Fat         0.078362
# 3           FDI19        15.10          Low Fat         0.052339
# 4           FDF24        15.50          Regular         0.042465
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Baking Goods  161.8868            OUT035                       2004
# 1   Snack Foods  140.2154            OUT045                       2002
# 2  Baking Goods  177.9370            OUT027                       1985
# 3          Meat  242.7512            OUT046                       1997
# 4  Baking Goods   81.5934            OUT010                       1998
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0       Small               Tier 2  Supermarket Type1          3275.7360
# ...

# %%
### WRITE YOUR CODE HERE

# %% [markdown]
# ----
#
# ####  `2. READ THE JSON DATA`
#
# ----

# %%
# read the json file
json_data = pd.read_json('/content/drive/My Drive/Assignment_ReadingFiles_Pandas/dataset/simple.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-b53086e59ac7> in <cell line: 2>()
#       1 # read the json file
# ----> 2 json_data = pd.read_json('/content/drive/My Drive/Assignment_ReadingFiles_Pandas/dataset/simple.json')
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#     816
#     817
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read(self)
#    1023                         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024                 else:
# ...

# %% [markdown]
# ---
#
# ***Open the JSON file in the text editor and see what can you do to read the file.***
#
# ---

# %%
#### WRITE YOUR CODE HERE

# %%
# read the json file
json_data = pd.read_json('/content/drive/My Drive/Assignment_ReadingFiles_Pandas/dataset/simple.json',lines=True)

# %%
json_data.head()
# Out:
#       name  age grade
# 0    Andew   12     A
# 1   Bhuvan   18     B
# 2  Clinton   11     A
# 3    Drake   12     C
# 4    Eisha   13     B

# %%
# The end
