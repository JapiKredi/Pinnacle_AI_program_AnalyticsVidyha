# %% [markdown]
# <a href="https://colab.research.google.com/github/JapiKredi/Pinnacle_AI_program_AnalyticsVidyha/blob/main/Assignment_Pandas_Sorting%26Aggregating_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Sorting and Aggregating Data 📍 📍</h1></center>
#
# ---
#
# #### `READ THE DATASET`
#
# ---

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/My Drive/Assignment3/dataset/time_series.csv')

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.dtypes
# Out:
# ID           int64
# Datetime    object
# Count        int64
# dtype: object

# %% [markdown]
# #### `Convert the Datetime column to pandas datetime object`
#
# ---

# %%
# WRITE YOUR CODE HERE
data.Datetime = pd.to_datetime(data.Datetime)
# Out:
# <ipython-input-6-642bfdc72c2a>:2: UserWarning: Parsing dates in %d-%m-%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data.Datetime = pd.to_datetime(data.Datetime)

# %%
data.dtypes
# Out:
# ID                   int64
# Datetime    datetime64[ns]
# Count                int64
# dtype: object

# %% [markdown]
# ---
#
# ####  `Create the following features using the Datetime feature`
#
# - day of month
# - month
# - day of year
# - hour
#
# ---

# %%
# WRITE YOUR CODE HERE
data['month'] = data.Datetime.dt.month
data['month_name'] = data.Datetime.dt.month_name()
data['day_of_year'] = data.Datetime.dt.dayofyear
data['hour'] = data.Datetime.dt.hour

# %%
data.head()
# Out:
#    ID            Datetime  Count  month month_name  day_of_year  hour
# 0   0 2012-08-25 00:00:00      8      8     August          238     0
# 1   1 2012-08-25 01:00:00      2      8     August          238     1
# 2   2 2012-08-25 02:00:00      6      8     August          238     2
# 3   3 2012-08-25 03:00:00      2      8     August          238     3
# 4   4 2012-08-25 04:00:00      2      8     August          238     4

# %% [markdown]
# ---
#
# #### `Consider the following dataframe`
#
# ---

# %%
sample_df = pd.DataFrame({
    'id'   :  [1, 2, 3, 4, 5],
    'name' :  [ 'Akash', 'Akansha', 'Naman', 'Pulkit', 'Anand'],
    'marks':  [ 22, 23, 43, 41, 12]
})
sample_df
# Out:
#    id     name  marks
# 0   1    Akash     22
# 1   2  Akansha     23
# 2   3    Naman     43
# 3   4   Pulkit     41
# 4   5    Anand     12

# %% [markdown]
# #### Sort the  dataframe by `marks` column in descending order
#
# ---

# %%
# WRITE YOUR CODE HERE
sample_df.sort_values(by='marks', ascending=False)
# Out:
#    id     name  marks
# 2   3    Naman     43
# 3   4   Pulkit     41
# 1   2  Akansha     23
# 0   1    Akash     22
# 4   5    Anand     12

# %% [markdown]
# #### Consider another dataframe city
# ---

# %%
city = pd.DataFrame({
    'name' : ['Akash', 'Akansha', 'Pulkit', 'Anand', 'Naman'],
    'city' : ['Delhi', 'Gurugram', 'Gurugram', 'Delhi', 'Noida']
})
city
# Out:
#       name      city
# 0    Akash     Delhi
# 1  Akansha  Gurugram
# 2   Pulkit  Gurugram
# 3    Anand     Delhi
# 4    Naman     Noida

# %% [markdown]
# ***Use the dataframe `sample_df` and `city` and find out the marks of students who live in Gurugram.***
#
# ---

# %%
### Write your code here
merged_df = pd.merge(sample_df, city, on='name', how='left')

# %%
merged_df.head()
# Out:
#    id     name  marks      city
# 0   1    Akash     22     Delhi
# 1   2  Akansha     23  Gurugram
# 2   3    Naman     43     Noida
# 3   4   Pulkit     41  Gurugram
# 4   5    Anand     12     Delhi

# %%
marks_students_Gurugram = merged_df[merged_df['city'] == 'Gurugram']['marks']
marks_students_Gurugram
# Out:
# 1    23
# 3    41
# Name: marks, dtype: int64

# %% [markdown]
# ####Answer to the question:
# The marks of the students living Gurugram are: 23 and 41

# %% [markdown]
# #### `READ THE BIG MART SALES DATA`
#
# ---

# %%
big_mart_data = pd.read_csv('/content/drive/My Drive/Assignment3/dataset/big_mart_sales.csv')

# %%
big_mart_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### Find out the number of unique `Item_Type` in each of the `Outlet_Identifier`
#
# ---

# %%
# WRITE YOUR CODE HERE
big_mart_data.groupby('Outlet_Identifier')['Item_Type'].nunique()
# Out:
# Outlet_Identifier
# OUT010    16
# OUT013    16
# OUT017    16
# OUT018    16
# OUT019    16
# OUT027    16
# OUT035    16
# OUT045    16
# OUT046    16
# OUT049    16
# Name: Item_Type, dtype: int64

# %% [markdown]
# #### Find out the average `Item_Outlet_Sales` for each category of `Outlet_Size`
#
# ---

# %%
# WRITE YOUR CODE HERE
big_mart_data.groupby('Outlet_Size')['Item_Outlet_Sales'].mean()
# Out:
# Outlet_Size
# High      2298.995256
# Medium    2681.603542
# Small     1912.149161
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### Select only the categorical variables from the dataframe and use `get_dummies` function to convert those into the numerical ones.
#
# ---

# %%
# WRITE YOUR CODE HERE
categorical_df = big_mart_data.select_dtypes(include=['object'])
categorical_df.head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# 1      Medium               Tier 3  Supermarket Type2
# 2      Medium               Tier 1  Supermarket Type1
# 3         NaN               Tier 3      Grocery Store
# 4        High               Tier 3  Supermarket Type1

# %%
categorical_df.shape
# Out:
# (8523, 7)

# %%
categorical_df = pd.get_dummies(categorical_df)
categorical_df.head()
# Out:
#    Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# 0                  False                  False                  False
# 1                  False                  False                  False
# 2                  False                  False                  False
# 3                  False                  False                  False
# 4                  False                  False                  False
#
#    Item_Identifier_DRB25  Item_Identifier_DRB48  Item_Identifier_DRC01  \
# ...

# %%
categorical_df.shape
# Out:
# (8523, 1600)

# %%
# As you can see the usage of the get_dummies function on the categorical_df has increased the number of columns from 7 to 1,600!

# %%
# The end
