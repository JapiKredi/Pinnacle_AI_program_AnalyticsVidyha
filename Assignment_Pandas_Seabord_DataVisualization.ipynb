# %% [markdown]
# <a href="https://colab.research.google.com/github/JapiKredi/Pinnacle_AI_program_AnalyticsVidyha/blob/main/Assignment_Pandas_Seabord_DataVisualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Assignment: Data Visualization 📍 📍</h1></center>
#
#
# ---
#
# #### `READ THE BIG MART SALES DATA`
#
# ---

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_BM = pd.read_csv('/content/drive/My Drive/Assignment4_Pandas/dataset/big_mart_sales.csv')

# %%
data_BM.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# sales by outlet size
sales_by_outlet_size = data_BM.groupby('Outlet_Size').Item_Outlet_Sales.mean()

# sort by sales
sales_by_outlet_size.sort_values(inplace=True)

x = sales_by_outlet_size.index.tolist()
y = sales_by_outlet_size.values.tolist()


# set xticks
plt.xticks(labels=x, ticks=np.arange(len(x)))

plt.bar(x, y, color=['red', 'orange', 'magenta']);

# %% [markdown]
# #### `Do the following edits in the above plot`
#
# - Add the x-axis label as `Outlet Size`
# - Add the y-axis label as `Sales`
# - Add the plot title as `Mean Sales for each outlet type`
#
# ---

# %%
## WRITE YOUR CODE HERE

# Define the custom order for Outlet_Size
size_order = pd.CategoricalDtype(categories=['Small', 'Medium', 'High'], ordered=True)
data_BM['Outlet_Size'] = data_BM['Outlet_Size'].astype(size_order)

# Calculate mean sales by outlet size
sales_by_outlet_size = data_BM.groupby('Outlet_Size', observed=True).Item_Outlet_Sales.mean()

# Sort by the custom order
sales_by_outlet_size = sales_by_outlet_size.sort_index()

x = sales_by_outlet_size.index.tolist()
y = sales_by_outlet_size.values.tolist()

# Create the plot
fig, ax = plt.subplots()

# Add the x-axis label as Outlet Size
ax.set_xlabel("Outlet Size")
# Add the y-axis label as Sales
ax.set_ylabel("Sales")
# Add the plot title as Mean Sales for each outlet type
ax.set_title("Mean Sales for each outlet type") # I am using ax.set_title as there was a conflict with plt.title being set as an environment variable in Google Colab

# Set xticks
ax.set_xticks(np.arange(len(x)))
ax.set_xticklabels(x)

# Plot the bar chart
ax.bar(x, y, color=['red', 'orange', 'magenta'])

# Show the plot
plt.show()

# %% [markdown]
# ---
#
#
# ***Create a scatter plot to show the relative distribution of `Item_Weight` and `Item_Visibility`.***
#
#
# ---

# %%
## WRITE YOUR CODE HERE
plt.xlabel('Item_Weight')
plt.ylabel('Item_Visibility')

plt.scatter(data_BM['Item_Weight'], data_BM['Item_Visibility'], color='blue')
plt.show()

# %% [markdown]
# ---
#
# ***Create a `box plot` of the variable `Item_Outlet_Sales` using the seaborn.***
#
#
# ---

# %%
# WRITE YOUR CODE HERE
import matplotlib.pyplot as plt

# Assuming data_BM is your DataFrame
data = data_BM[['Item_Outlet_Sales']]

# Create outlier point shape
red_diamond = dict(markerfacecolor='r', marker='D')

# Create the plot
fig, ax = plt.subplots()

# Set title using the axis object
ax.set_title("Distribution of Item Outlet Sales")

# Make the boxplot
ax.boxplot(data.values, labels=['Item Outlet Sales'], flierprops=red_diamond)

# Show the plot
plt.show()

# %%
# The end
