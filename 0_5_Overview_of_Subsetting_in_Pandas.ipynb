# %% [markdown]
# <a href="https://colab.research.google.com/github/JapiKredi/Pinnacle_AI_program_AnalyticsVidyha/blob/main/0_5_Overview_of_Subsetting_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# ---
#
# <center><h1>📍 📍 Overview of Subsetting in Pandas 📍 📍</h1></center>
#
#
#
# ---
#
# #### `TABLE OF CONTENTS`
#
# - What is an index?
# - How to subset first N rows based on their position index?
# - Can we change the index?
# - Will the index be always numeric?
# - How to subset the data based on a label of the index?
# - Can we reset the index?
# - How to subset the data based on a value of a column?
#
# ---
#
#
# #### `READ THE DATA`
#
# - In this notebook, we are going to use the big mart sales data that we have used previously. It is stored in the folder name `datasets`.

# %%
# import the pandas library
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the big mart sales data
#data = pd.read_csv('/content/drive/My Drive/big_mart_sales.csv')
data = pd.read_csv('/content/drive/My Drive/Overviewofsubsetting/datasets/big_mart_sales.csv')

# %% [markdown]
# #### `WHAT IS INDEX?`
#
# ![](index.png)
#
# -  You can see the index object by `DataFrame.index`.

# %%
# index of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=8523, step=1)

# %% [markdown]
# ***So, In this case, we have the numeric index value start from the 0 and ends at 8523.***

# %%
# no. of rows and columns in the data
data.shape
# Out:
# (8523, 12)

# %%
# column index
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# #### `HOW TO SUBSET FIRST 'N' ROWS BASED ON THEIR POSITION INDEX?`

# %%
# view the top rows of the data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ---
#
# #### `CAN WE CHANGE THE INDEX?`
#
# ---
#
# ***The answer is `Yes`. We can change the index. Let's see how?***
#
# ---

# %% [markdown]
# #### Create a random list of 8523 numbers and set it as the index
# ---

# %%
# create random list
import random
random_list = [random.randint(1, 8523) for i in range(8523)]

# %%
random_list
# Out:
# [3619,
#  3565,
#  2650,
#  6079,
#  2213,
#  1064,
#  8323,
#  80,
#  2079,
#  6681,
#  420,
#  8192,
#  5580,
#  7046,
#  2945,
#  7419,
#  7191,
#  7601,
#  8295,
#  4284,
#  4656,
#  6083,
#  6214,
#  518,
#  4500,
#  1343,
#  6402,
#  2199,
#  1159,
#  2586,
#  3884,
#  2171,
#  3111,
#  289,
#  7152,
#  565,
#  746,
#  399,
#  4376,
#  7211,
#  2443,
#  1984,
#  6329,
#  5808,
#  7508,
#  4611,
#  5334,
#  275,
#  4073,
#  4723,
#  1024,
#  2001,
#  258,
#  6516,
#  1321,
#  8017,
#  5078,
#  6147,
#  3909,
#  5150,
#  8152,
#  2558,
#  8260,
#  4636,
#  2777,
#  5961,
#  2940,
#  1954,
#  7594,
#  4046,
#  608,
#  4845,
#  2585,
#  2809,
#  5713,
#  1222,
#  6343,
#  5909,
#  5493,
#  2294,
#  3548,
#  7584,
#  6064,
#  96,
#  5871,
#  4397,
#  2365,
#  2314,
#  6193,
#  2555,
#  5078,
#  721,
#  4547,
#  4062,
#  3651,
#  3610,
#  6376,
#  137,
#  458,
#  895,
#  8523,
#  8019,
#  6977,
#  3373,
#  969,
#  563,
#  7994,
#  3491,
#  2652,
#  5739,
#  4678,
#  6895,
#  2831,
#  1108,
#  2320,
#  4727,
#  4425,
#  5641,
#  7411,
#  4248,
#  7160,
#  954,
#  3578,
#  4075,
#  6997,
#  2182,
#  4006,
#  2794,
#  3652,
#  8350,
#  6246,
#  6265,
#  1967,
#  4240,
#  7401,
#  1092,
#  5118,
#  2385,
#  7285,
#  1864,
#  3290,
#  533,
#  369,
#  2147,
#  4090,
#  172,
#  178,
#  5473,
#  5767,
#  3844,
#  4638,
#  5344,
#  5732,
#  1714,
#  5639,
#  2286,
#  2692,
#  2933,
#  8057,
#  2490,
#  2922,
#  4067,
#  967,
#  4719,
#  7234,
#  1292,
#  1407,
#  7794,
#  2725,
#  6383,
#  7117,
#  1351,
#  7184,
#  8318,
#  1990,
#  4787,
#  7726,
#  1890,
#  1537,
#  1893,
#  7109,
#  8139,
#  7074,
#  3355,
#  7897,
#  3530,
#  3300,
#  4731,
#  1698,
#  4770,
#  1135,
#  3179,
#  7805,
#  7543,
#  3684,
#  5188,
#  4840,
#  7793,
#  8185,
#  7192,
#  6614,
#  859,
#  150,
#  7143,
#  7666,
#  91,
#  3745,
#  5523,
#  3723,
#  4513,
#  3781,
#  5977,
#  6366,
#  2349,
#  8140,
#  5157,
#  3566,
#  2814,
#  8419,
#  1057,
#  5115,
#  1617,
#  4163,
#  7444,
#  1402,
#  4144,
#  4336,
#  727,
#  2596,
#  3372,
#  4793,
#  6419,
#  5894,
#  771,
#  2336,
#  7637,
#  8457,
#  3300,
#  3610,
#  2200,
#  2252,
#  4634,
#  2440,
#  1209,
#  6488,
#  1662,
#  2477,
#  3223,
#  5477,
#  1253,
#  8130,
#  6763,
#  7363,
#  3370,
#  1420,
#  2866,
#  3928,
#  7267,
#  8442,
#  29,
#  6155,
#  4860,
#  5821,
#  3282,
#  73,
#  7484,
#  6966,
#  629,
#  4732,
#  3606,
#  5293,
#  261,
#  1531,
#  910,
#  5396,
#  7533,
#  8046,
#  939,
#  7290,
#  3121,
#  1467,
#  868,
#  1922,
#  6674,
#  1655,
#  3103,
#  5835,
#  8349,
#  5059,
#  529,
#  4129,
#  969,
#  536,
#  3574,
#  4848,
#  2149,
#  3046,
#  3785,
#  8249,
#  3040,
#  21,
#  5196,
#  4181,
#  4094,
#  6642,
#  6669,
#  7410,
#  4285,
#  4983,
#  5325,
#  2877,
#  6507,
#  6921,
#  1693,
#  6387,
#  7198,
#  1277,
#  5614,
#  1777,
#  2967,
#  5140,
#  6441,
#  8182,
#  1401,
#  6624,
#  487,
#  1240,
#  4045,
#  7856,
#  1370,
#  2645,
#  2505,
#  4713,
#  1043,
#  8461,
#  5292,
#  3829,
#  5600,
#  2797,
#  4229,
#  4604,
#  7486,
#  783,
#  8482,
#  250,
#  2595,
#  5392,
#  7129,
#  140,
#  1050,
#  3004,
#  865,
#  7559,
#  5114,
#  2365,
#  2900,
#  5869,
#  1376,
#  7929,
#  3682,
#  1455,
#  3007,
#  6173,
#  960,
#  787,
#  667,
#  6211,
#  2469,
#  8480,
#  1558,
#  4688,
#  1185,
#  5695,
#  2024,
#  4070,
#  7634,
#  238,
#  4405,
#  19,
#  2204,
#  2562,
#  4347,
#  1354,
#  3680,
#  2169,
#  4466,
#  3718,
#  5498,
#  6147,
#  734,
#  2406,
#  4569,
#  7116,
#  320,
#  92,
#  7514,
#  4873,
#  4833,
#  3796,
#  7477,
#  4590,
#  7519,
#  4030,
#  1405,
#  5696,
#  6360,
#  1262,
#  2730,
#  1842,
#  1351,
#  5563,
#  645,
#  5373,
#  4021,
#  5904,
#  5243,
#  3917,
#  7862,
#  7050,
#  7591,
#  453,
#  5126,
#  3116,
#  2699,
#  5572,
#  5953,
#  8363,
#  1990,
#  4494,
#  1970,
#  5069,
#  813,
#  4640,
#  7163,
#  5382,
#  6727,
#  5798,
#  5256,
#  4919,
#  5470,
#  4537,
#  5401,
#  4808,
#  1119,
#  8027,
#  7606,
#  1091,
#  6711,
#  1025,
#  2253,
#  6565,
#  5777,
#  6236,
#  4695,
#  1243,
#  6622,
#  1587,
#  6084,
#  6401,
#  5930,
#  3962,
#  7811,
#  2841,
#  8047,
#  8024,
#  5040,
#  4380,
#  6462,
#  3260,
#  6738,
#  4035,
#  6595,
#  3598,
#  4923,
#  5036,
#  2892,
#  2755,
#  258,
#  4533,
#  3229,
#  7777,
#  5828,
#  6442,
#  3399,
#  3609,
#  3771,
#  749,
#  8183,
#  6710,
#  3676,
#  5794,
#  4578,
#  33,
#  721,
#  155,
#  6501,
#  8075,
#  4102,
#  576,
#  4745,
#  3927,
#  700,
#  2192,
#  5983,
#  3699,
#  7026,
#  6289,
#  5778,
#  5913,
#  3528,
#  5917,
#  4122,
#  3774,
#  7496,
#  6036,
#  6184,
#  5090,
#  1539,
#  5891,
#  4607,
#  293,
#  1704,
#  5204,
#  1362,
#  243,
#  339,
#  3209,
#  7305,
#  4706,
#  3974,
#  5300,
#  5444,
#  3210,
#  3435,
#  546,
#  4177,
#  4354,
#  7516,
#  1600,
#  5738,
#  1843,
#  7116,
#  1716,
#  4428,
#  4766,
#  1450,
#  8496,
#  4661,
#  45,
#  4006,
#  2993,
#  452,
#  4214,
#  2036,
#  5492,
#  3990,
#  5708,
#  6477,
#  282,
#  6385,
#  8212,
#  3610,
#  1331,
#  6441,
#  3515,
#  3474,
#  5229,
#  7721,
#  7001,
#  4373,
#  1099,
#  8297,
#  5450,
#  2952,
#  632,
#  5882,
#  360,
#  2613,
#  98,
#  95,
#  3256,
#  804,
#  1814,
#  1235,
#  6722,
#  4264,
#  4460,
#  8370,
#  8082,
#  4800,
#  5169,
#  2430,
#  3868,
#  5070,
#  8302,
#  6094,
#  6610,
#  319,
#  5008,
#  2801,
#  1810,
#  4295,
#  2903,
#  4228,
#  1332,
#  3484,
#  1645,
#  3481,
#  230,
#  7022,
#  4408,
#  4317,
#  7087,
#  2160,
#  5735,
#  735,
#  3705,
#  2860,
#  3424,
#  1755,
#  1927,
#  6462,
#  5285,
#  5236,
#  8366,
#  3946,
#  4094,
#  7020,
#  3377,
#  1827,
#  4141,
#  3036,
#  6315,
#  6635,
#  6940,
#  4036,
#  8400,
#  1699,
#  7103,
#  262,
#  10,
#  964,
#  3746,
#  68,
#  3928,
#  4680,
#  555,
#  1815,
#  7215,
#  8219,
#  2577,
#  6137,
#  5166,
#  713,
#  7971,
#  7441,
#  7364,
#  3171,
#  3799,
#  5336,
#  5558,
#  4043,
#  8108,
#  4478,
#  4205,
#  2460,
#  125,
#  1288,
#  3020,
#  990,
#  6129,
#  2479,
#  3378,
#  5011,
#  42,
#  1396,
#  6507,
#  6917,
#  6169,
#  4170,
#  627,
#  8042,
#  6285,
#  6405,
#  4697,
#  1060,
#  6096,
#  6453,
#  2126,
#  1617,
#  2733,
#  7083,
#  7449,
#  7977,
#  8358,
#  6500,
#  6170,
#  6034,
#  4999,
#  2504,
#  5321,
#  8491,
#  781,
#  7266,
#  4192,
#  6700,
#  4107,
#  6222,
#  5877,
#  4902,
#  759,
#  2267,
#  8516,
#  6083,
#  7778,
#  7790,
#  2313,
#  5622,
#  7444,
#  4893,
#  2850,
#  2735,
#  7491,
#  1758,
#  4140,
#  8128,
#  7198,
#  2911,
#  4254,
#  1758,
#  5135,
#  4089,
#  4394,
#  7606,
#  931,
#  550,
#  8217,
#  244,
#  1460,
#  246,
#  8344,
#  7174,
#  7388,
#  324,
#  2266,
#  946,
#  6087,
#  3743,
#  1150,
#  3678,
#  7456,
#  3056,
#  4479,
#  1589,
#  3741,
#  1501,
#  1781,
#  8395,
#  201,
#  2184,
#  2591,
#  7932,
#  8479,
#  5619,
#  2644,
#  3314,
#  5611,
#  3039,
#  7445,
#  2534,
#  7525,
#  5937,
#  5821,
#  2967,
#  3204,
#  465,
#  2923,
#  1159,
#  6923,
#  1627,
#  2327,
#  1981,
#  6724,
#  1991,
#  2767,
#  743,
#  1272,
#  3303,
#  7561,
#  6926,
#  7446,
#  3173,
#  6131,
#  7205,
#  922,
#  7116,
#  434,
#  5517,
#  6163,
#  5073,
#  958,
#  1582,
#  4894,
#  5541,
#  3904,
#  2575,
#  4220,
#  4192,
#  2264,
#  5705,
#  531,
#  1495,
#  2650,
#  5004,
#  3359,
#  8450,
#  4149,
#  5016,
#  1389,
#  1914,
#  2018,
#  6651,
#  2741,
#  4629,
#  5711,
#  4796,
#  5811,
#  8178,
#  1605,
#  1369,
#  677,
#  38,
#  4885,
#  4765,
#  2275,
#  7576,
#  3016,
#  5238,
#  8220,
#  2652,
#  1395,
#  839,
#  8196,
#  7500,
#  6585,
#  6680,
#  7867,
#  578,
#  4224,
#  2150,
#  442,
#  4844,
#  4365,
#  6179,
#  4434,
#  4451,
#  6384,
#  3299,
#  4157,
#  263,
#  3586,
#  6505,
#  7450,
#  5608,
#  1144,
#  8388,
#  3010,
#  4009,
#  3372,
#  4900,
#  6673,
#  3622,
#  5215,
#  1577,
#  445,
#  6647,
#  6030,
#  6808,
#  8452,
#  2708,
#  8211,
#  4070,
#  4652,
#  6366,
#  2344,
#  6205,
#  1012,
#  4712,
#  28,
#  260,
#  6941,
#  61,
#  5741,
#  6922,
#  3859,
#  8076,
#  3044,
#  6942,
#  1475,
#  609,
#  6522,
#  2732,
#  3777,
#  1904,
#  1273,
#  3733,
#  7436,
#  6161,
#  7603,
#  4114,
#  5189,
#  3395,
#  7533,
#  1211,
#  6219,
#  5281,
#  755,
#  2623,
#  4322,
#  6783,
#  1969,
#  5305,
#  598,
#  6036,
#  6167,
#  129,
#  6695,
#  2850,
#  7615,
#  6894,
#  3145,
#  1818,
#  75,
#  8429,
#  3493,
#  566,
#  4115,
#  3206,
#  2473,
#  1166,
#  7769,
#  6969,
#  4284,
#  8112,
#  2766,
#  5006,
#  1354,
#  741,
#  1080,
#  6296,
#  6666,
#  8446,
#  363,
#  1142,
#  890,
#  4820,
#  5320,
#  4851,
#  4774,
#  4957,
#  588,
#  1725,
#  4265,
#  4573,
#  5310,
#  5489,
#  3096,
#  4998,
#  7672,
#  8175,
#  5147,
#  1095,
#  8472,
#  2006,
#  417,
#  8406,
#  6329,
#  5716,
#  7182,
#  3734,
#  4146,
#  8022,
#  1754,
#  8,
#  1571,
#  3480,
#  3627,
#  4351,
#  4576,
#  2845,
#  642,
#  820,
#  987,
#  6606,
#  3396,
#  2136,
#  3461,
#  785,
#  6944,
#  6437,
#  ...]

# %%
# set the index
data.index = random_list

# %%
data.head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3619           FDA15         9.30          Low Fat         0.016047
# 3565           DRC01         5.92          Regular         0.019278
# 2650           FDN15        17.50          Low Fat         0.016760
# 6079           FDX07        19.20          Regular         0.000000
# 2213           NCD19         8.93          Low Fat         0.000000
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3619                  Dairy  249.8092            OUT049
# 3565            Soft Drinks   48.2692            OUT018
# 2650                   Meat  141.6180            OUT049
# 6079  Fruits and Vegetables  182.0950            OUT010
# 2213              Household   53.8614            OUT013
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 3619                       1999      Medium               Tier 1
# 3565                       2009      Medium               Tier 3
# 2650                       1999      Medium               Tier 1
# 6079                       1998         NaN               Tier 3
# 2213                       1987        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 3619  Supermarket Type1          3735.1380
# 3565  Supermarket Type2           443.4228
# 2650  Supermarket Type1          2097.2700
# 6079      Grocery Store           732.3800
# 2213  Supermarket Type1           994.7052

# %% [markdown]
# ***Set another column of the dataframe as the index. We will use the set_index function. You can read more about here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html'***
#
# ---

# %%
# 1. change the index of the dataframe
# 2. drop=True is used to drop the column that's set as index
# 3. inplace=True is used to make changes in the original dataframe
# data = pd.read_csv('datasets/big_mart_sales.csv')

data.set_index('Outlet_Establishment_Year', drop=True, inplace=True)

# %%
# example of a label based index
data.head()
# Out:
#                           Item_Identifier  Item_Weight Item_Fat_Content  \
# Outlet_Establishment_Year
# 1999                                FDA15         9.30          Low Fat
# 2009                                DRC01         5.92          Regular
# 1999                                FDN15        17.50          Low Fat
# 1998                                FDX07        19.20          Regular
# 1987                                NCD19         8.93          Low Fat
#
#                            Item_Visibility              Item_Type  Item_MRP  \
# Outlet_Establishment_Year
# 1999                              0.016047                  Dairy  249.8092
# 2009                              0.019278            Soft Drinks   48.2692
# 1999                              0.016760                   Meat  141.6180
# 1998                              0.000000  Fruits and Vegetables  182.0950
# 1987                              0.000000              Household   53.8614
#
#                           Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Outlet_Establishment_Year
# 1999                                 OUT049      Medium               Tier 1
# 2009                                 OUT018      Medium               Tier 3
# 1999                                 OUT049      Medium               Tier 1
# 1998                                 OUT010         NaN               Tier 3
# 1987                                 OUT013        High               Tier 3
#
#                                  Outlet_Type  Item_Outlet_Sales
# Outlet_Establishment_Year
# 1999                       Supermarket Type1          3735.1380
# 2009                       Supermarket Type2           443.4228
# 1999                       Supermarket Type1          2097.2700
# 1998                           Grocery Store           732.3800
# 1987                       Supermarket Type1           994.7052

# %%
data.index
# Out:
# Index([1999, 2009, 1999, 1998, 1987, 2009, 1987, 1985, 2002, 2007,
#        ...
#        2004, 2002, 2009, 2009, 1997, 1987, 2002, 2004, 2009, 1997],
#       dtype='int64', name='Outlet_Establishment_Year', length=8523)

# %% [markdown]
# ---
#
# ### `WILL THE INDEX BE ALWAYS NUMERIC?`
#
# ---
#
#
# ***No, We can also have categorical variables as the index of a dataframe.***
#
# ---

# %%
# reset the index
data.set_index('Item_Identifier', drop= True, inplace=True)

# %%
# view the top rows of the data
data.head()
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility  \
# Item_Identifier
# FDA15                   9.30          Low Fat         0.016047
# DRC01                   5.92          Regular         0.019278
# FDN15                  17.50          Low Fat         0.016760
# FDX07                  19.20          Regular         0.000000
# NCD19                   8.93          Low Fat         0.000000
#
#                              Item_Type  Item_MRP Outlet_Identifier  \
# Item_Identifier
# FDA15                            Dairy  249.8092            OUT049
# DRC01                      Soft Drinks   48.2692            OUT018
# FDN15                             Meat  141.6180            OUT049
# FDX07            Fruits and Vegetables  182.0950            OUT010
# NCD19                        Household   53.8614            OUT013
#
#                 Outlet_Size Outlet_Location_Type        Outlet_Type  \
# Item_Identifier
# FDA15                Medium               Tier 1  Supermarket Type1
# DRC01                Medium               Tier 3  Supermarket Type2
# FDN15                Medium               Tier 1  Supermarket Type1
# FDX07                   NaN               Tier 3      Grocery Store
# NCD19                  High               Tier 3  Supermarket Type1
#
#                  Item_Outlet_Sales
# Item_Identifier
# FDA15                    3735.1380
# DRC01                     443.4228
# FDN15                    2097.2700
# FDX07                     732.3800
# NCD19                     994.7052

# %%
# index of the data
data.index
# Out:
# Index(['FDA15', 'DRC01', 'FDN15', 'FDX07', 'NCD19', 'FDP36', 'FDO10', 'FDP10',
#        'FDH17', 'FDU28',
#        ...
#        'FDH31', 'FDA01', 'FDH24', 'NCJ19', 'FDF53', 'FDF22', 'FDS36', 'NCJ29',
#        'FDN46', 'DRG01'],
#       dtype='object', name='Item_Identifier', length=8523)

# %% [markdown]
# ---
#
# #### `HOW TO SUBSET THE DATA BASED ON THE LABEL OF THE INDEX?`
#
# - We can subset the data based on the label of the index using the loc function.
# ---

# %%
data.loc['FDA15']
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# Item_Identifier
# FDA15            249.8092            OUT049      Medium               Tier 1
# FDA15            250.2092            OUT045         NaN               Tier 2
# FDA15            248.5092            OUT035       Small               Tier 2
# FDA15            249.6092            OUT018      Medium               Tier 3
# FDA15            248.9092            OUT010         NaN               Tier 3
# FDA15            250.6092            OUT013        High               Tier 3
# FDA15            249.5092            OUT027      Medium               Tier 3
# FDA15            248.8092            OUT017         NaN               Tier 2
#
#                        Outlet_Type  Item_Outlet_Sales
# Item_Identifier
# FDA15            Supermarket Type1          3735.1380
# FDA15            Supermarket Type1          5976.2208
# FDA15            Supermarket Type1          6474.2392
# FDA15            Supermarket Type2          5976.2208
# FDA15                Grocery Store           498.0184
# FDA15            Supermarket Type1          6474.2392
# FDA15            Supermarket Type3          6474.2392
# FDA15            Supermarket Type1          5976.2208

# %% [markdown]
# ***What if we want to change the index back to positional?***
#
# ---
#
# #### `CAN WE RESET THE INDEX?`
#
# ***Yes, we can reset the index. Let's see how? We will use the reset_index function. You can read more about here: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.reset_index.html***
#
# ---

# %%
# reset the index
data.reset_index(inplace=True)

# %%
# view the top rows of the data
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                  Dairy  249.8092            OUT049      Medium
# 1            Soft Drinks   48.2692            OUT018      Medium
# 2                   Meat  141.6180            OUT049      Medium
# 3  Fruits and Vegetables  182.0950            OUT010         NaN
# 4              Household   53.8614            OUT013        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700
# 3               Tier 3      Grocery Store           732.3800
# 4               Tier 3  Supermarket Type1           994.7052

# %% [markdown]
# #### `HOW TO SUBSET THE DATA BASED ON A VALUE OF A COLUMN?`
#
# ---

# %%
data[data['Item_Type'] == 'Dairy']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 0              FDA15        9.300          Low Fat         0.016047     Dairy
# 11             FDA03       18.500          Regular         0.045464     Dairy
# 19             FDU02       13.350          Low Fat         0.102492     Dairy
# 28             FDE51        5.925          Regular         0.161467     Dairy
# 30             FDV38       19.250          Low Fat         0.170349     Dairy
# ...              ...          ...              ...              ...       ...
# 8424           FDC39        7.405          Low Fat         0.159165     Dairy
# 8447           FDS26       20.350          Low Fat         0.089975     Dairy
# 8448           FDV50       14.300          Low Fat         0.123071     Dairy
# 8457           FDY50        5.800          Low Fat         0.130931     Dairy
# 8512           FDR26       20.700          Low Fat         0.042801     Dairy
#
#       Item_MRP Outlet_Identifier Outlet_Size Outlet_Location_Type  \
# 0     249.8092            OUT049      Medium               Tier 1
# 11    144.1102            OUT046       Small               Tier 1
# 19    230.5352            OUT035       Small               Tier 2
# 28     45.5086            OUT010         NaN               Tier 3
# 30     55.7956            OUT010         NaN               Tier 3
# ...        ...               ...         ...                  ...
# 8424  207.1296            OUT035       Small               Tier 2
# 8447  261.6594            OUT017         NaN               Tier 2
# 8448  121.1730            OUT018      Medium               Tier 3
# 8457   89.9172            OUT035       Small               Tier 2
# 8512  178.3028            OUT013        High               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 0     Supermarket Type1          3735.1380
# 11    Supermarket Type1          2187.1530
# 19    Supermarket Type1          2748.4224
# 28        Grocery Store           178.4344
# 30        Grocery Store           163.7868
# ...                 ...                ...
# 8424  Supermarket Type1          3739.1328
# 8447  Supermarket Type1          7588.1226
# 8448  Supermarket Type2          2093.9410
# 8457  Supermarket Type1          1516.6924
# 8512  Supermarket Type1          2479.4392
#
# [682 rows x 11 columns]

# %% [markdown]
# ----
#
# #### `WE WILL SEE HOW TO SUBSET THE DATA BASED ON POSITION, LABEL AND VALUES IN DETAIL`
#
# ---
