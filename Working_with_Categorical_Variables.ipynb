# %% [markdown]
# <a href="https://colab.research.google.com/github/JapiKredi/Pinnacle_AI_program_AnalyticsVidyha/blob/main/Working_with_Categorical_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading the data

# %%
# importing required libraries
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#loading the data
data = pd.read_csv('/content/drive/My Drive/Working_with_Categorical_Variables/titanic_train.csv')
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Missing Values

# %%
#missing values in the data
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# - Age and Cabin have a very high number of missing values
# - Embarked has very low number of missing values

# %% [markdown]
# ## Imputing Missing Values Using central tendency

# %%
# finding mean value
mean_val = data['Age'].mean()
mean_val
# Out:
# 29.69911764705882

# %%
# making a copy
data_cleaned = data.copy()

#imputing missing values
data_cleaned['Age'] = data['Age'].fillna(value = mean_val)
data_cleaned['Age'].isnull().sum()
# Out:
# 0

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
mode_val = data['Embarked'].mode()[0]
mode_val
# Out:
# 'S'

# %%
data_cleaned['Embarked'] = data['Embarked'].fillna(value = mode_val)

# %% [markdown]
# ## Dealing with Categorical Variables

# %%
#Categorical variables in the data
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
categorical_cols = ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']

# %%
#number of unique values
data[categorical_cols].nunique()
# Out:
# Name        891
# Sex           2
# Ticket      681
# Cabin       147
# Embarked      3
# dtype: int64

# %% [markdown]
# - Can One-hot-Encode Sex and Embarked
# - Deal with them differently (extract features)
# - Name, Ticket and Cabin (when encoded) will have zeros

# %% [markdown]
# ## One-hot Encoding

# %%
pd.get_dummies(data['Embarked']).head()
# Out:
#        C      Q      S
# 0  False  False   True
# 1   True  False  False
# 2  False  False   True
# 3  False  False   True
# 4  False  False   True

# %%
data_cleaned = data_cleaned.drop(['Name','Ticket','Cabin'], axis=1)

# %%
data_cleaned = pd.get_dummies(data_cleaned)
data_cleaned.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  \
# 0            1         0       3  22.0      1      0   7.2500       False
# 1            2         1       1  38.0      1      0  71.2833        True
# 2            3         1       3  26.0      0      0   7.9250        True
# 3            4         1       1  35.0      1      0  53.1000        True
# 4            5         0       3  35.0      0      0   8.0500       False
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0      True       False       False        True
# 1     False        True       False       False
# 2     False       False       False        True
# 3     False       False       False        True
# 4      True       False       False        True

# %% [markdown]
# - SibSp and Parch hold discrete values
# - We can convert them into separate columns as well

# %% [markdown]
# ## Label Encoding

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## map function

data['Embarked'].map({'Q': 0, 'S': 1, 'C':2})
# Out:
# 0      1.0
# 1      2.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 886    1.0
# 887    1.0
# 888    1.0
# 889    2.0
# 890    0.0
# Name: Embarked, Length: 891, dtype: float64

# %%
data['Embarked'] = data['Embarked'].map({'Q': 0, 'S': 1, 'C':2})
data['Embarked'].head()
# Out:
# 0    1.0
# 1    2.0
# 2    1.0
# 3    1.0
# 4    1.0
# Name: Embarked, dtype: float64
